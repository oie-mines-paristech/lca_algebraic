# %% [markdown]
# # Imports
#
# Besides external libraries, we import several function from the local file : `utils.py`

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import time
import matplotlib.pyplot as plt
import numpy as np
import brightway2 as bw

# Custom utils defined for inter-acv
from utils import *
from expression import *

# %% [markdown]
# # Init brightway2 and databases

# %%
# Setup bw2
bw.projects.set_current('B_Publication')
bw.bw2setup()

# Import Ecoinvent DB (if not already done)
# Update the PATH to suit your installation
importDb(ECOINVENT_DB_NAME, './ecoinvent 3.4_cutoff_ecoSpold02/datasets')

# We use a separate DB for defining our model, reset it beforehand
resetDb(ACV_DB_NAME)

# Parameters are stored at project level : reset them
resetParams()
# Out:
# Biosphere database already present!!! No setup is needed
# Database 'ecoinvent 3.4 cut off' has already been imported
# Db incer-acv was here. Reseting it

# %% [markdown]
# # Define parameters
#
# We define the parameters of the model.
#
# The numeric parametes are instances of sympy' 'Symbol' . Thus, any python arithmetic expression composed of parameters will not result into direct evaluation, but the creation of a symbolic formula that can be manipulated later.

# %%
# Example 'float' parameter
a = newParamDef(
    'a', 
    ParamType.NUMBER, 
    default=0.5, 
    description="hello world")

b = newParamDef(
    'b', 
    ParamType.NUMBER, 
    default=0.5, 
    description="foo bar")

# Example 'enum' parameter, acting like a switch between several possibilities
# Enum parameters are not Symbol themselves
# They are a facility to represent many parameters at once '<paramName>_<enumValue>' 
# and should be used with the 'switch' method 
elec_switch_param = newParamDef(
    'elec_switch_param', 
    ParamType.ENUM, 
    values=["us", "eu"], 
    default="us", 
    description="Switch on electricty mix")
# Out:
# -----------------------------------------------------------------
# Exception                       Traceback (most recent call last)
# <ipython-input-13-89f3b7394164> in <module>
#       4     ParamType.NUMBER,
#       5     default=0.5,
# ----> 6     description="hello world")
#       7
#       8 b = newParamDef(
#
# ~/acv/utils.py in newParamDef(name, type, **kwargs)
#     224     # Put it in local registry (in memory)
#     225     if name in param_registry:
# --> 226         raise Exception("Param %s already defined" % name)
#     227     param_registry[name] = param
#     228
#
# Exception: Param a already defined

# %% [markdown]
# # Get references to background activities and products
#
# `utils` provide two functions for easy and fast search of activities in reference databases :
# * **findBioAct** : Search activity in **biosphere3** db
# * **findTechAct** : Search activity in **ecoinvent** db

# %%
# Biosphere activities
ground_occupuation = findBioAct('Occupation, industrial area')
heat = findBioAct('Heat, waste', categories=['air'])

# Technosphere activities
alu = findTechAct("aluminium alloy production", "RER")

# Elec 
eu_elec = findTechAct("market group for electricity, medium voltage", 'ENTSO-E')
us_elec = findTechAct("market group for electricity, medium voltage", 'US')

# %% [markdown]
# # Define the model
#
# The model is defined as a nested combination of reference activities and amount.
# Amounts are defined either as constant float values or algebric formulas implying the parameters defined above.

# %%
# Create new, parametrized activity

# You can create a virtual "switch" activity combining an enum param and several other activities 
elec_switch = switch(elec_switch_param, {
    "us" : us_elec,
    "eu" : eu_elec})

# Create a new activity
activity1 = newActivity(
    name="act1", unit="kg", # Any extra named arg will be added as activity attribute
    exchanges= { # We define exhanges as a dict of 'activity : amount'
        ground_occupuation:3 + a, # Amount can be a fixed value 
        heat: b + 0.2,
        elec_switch:4}) # Amount can be a Sympy expression (any arithmetic expression of Parameters)

# The final model is just the root activity referencing the others
model = newActivity("model", "kg", {
        activity1 : b * 5 + a + 1, # Reference the activity we just created
        heat: 3,
        alu:0.4 * a})

# %%
# Print_act displays activities as "pandas" tables
print_act(activity1) 
print_act(model)
          
# Note that symbolic expressions have not been evaluated at this stage
# Out:
#                                                    amount /formula  \
# 'Occupation, industrial area' (square meter-yea...           a + 3
# 'Heat, waste' (megajoule, None, ('air',))                  b + 0.2
# 'elec_switch_param switch' (kilowatt hour, GLO,...               4
#
#                                                                  unit  \
# 'Occupation, industrial area' (square meter-yea...  square meter-year
# 'Heat, waste' (megajoule, None, ('air',))                   megajoule
# 'elec_switch_param switch' (kilowatt hour, GLO,...      kilowatt hour
#
#                                                             type
# 'Occupation, industrial area' (square meter-yea...     biosphere
# 'Heat, waste' (megajoule, None, ('air',))              biosphere
# 'elec_switch_param switch' (kilowatt hour, GLO,...  technosphere
#                                                    amount /formula       unit  \
# 'act1' (kg, GLO, None)                                 a + 5*b + 1         kg
# 'Heat, waste' (megajoule, None, ('air',))                        3  megajoule
# 'aluminium alloy production, AlMg3' (kilogram, ...           0.4*a   kilogram
#
#                                                             type
# 'act1' (kg, GLO, None)                              technosphere
# 'Heat, waste' (megajoule, None, ('air',))              biosphere
# 'aluminium alloy production, AlMg3' (kilogram, ...  technosphere

# %% [markdown]
# # Select the impacts to consider

# %%
# List of impacts to consider
impacts = [m for m in bw.methods if 'ILCD 1.0.8 2016' in str(m) and 'no LT' in str(m)]

# %% [markdown]
# # Compute LCA
#
# We provide two methods to compute LCA :
# * **multiLCA** : It uses brightway2 parametric capabilities. It is much slower and kept for comparing results.
# * **multiLCAAlgebric** : It computes an algebric expression of the model and computes LCA once for all the background activities. Then it express each impact as a function of the parameter. This expression is compiled into 'numpy' native code, for fast computation on vectors of samples. This version is 1 million time faster.

# %%
# Uses brightway2 parameters
multiLCA(us_elec, impacts, 
                   
    # Parameters of the model
    a=1, 
    b=2, 
    elec_switch_param="us")
# Out:
#                                   mineral, fossils and renewables  GWP 100a  \
# 379388913fee422a915764b6a021fd91                         0.000003  0.662856
#
#                                   freshwater and terrestrial acidification  \
# 379388913fee422a915764b6a021fd91                                  0.002418
#
#                                   freshwater ecotoxicity  \
# 379388913fee422a915764b6a021fd91                0.195917
#
#                                   freshwater eutrophication  \
# 379388913fee422a915764b6a021fd91                   0.000079
#
#                                   ionising radiation  marine eutrophication  \
# 379388913fee422a915764b6a021fd91        6.013195e-07               0.000281
#
#                                   terrestrial eutrophication  \
# 379388913fee422a915764b6a021fd91                    0.003751
#
#                                   carcinogenic effects  ionising radiation  \
# 379388913fee422a915764b6a021fd91          5.199518e-09            0.077193
#
#                                   non-carcinogenic effects  \
# 379388913fee422a915764b6a021fd91              4.209638e-08
#
#                                   ozone layer depletion  \
# 379388913fee422a915764b6a021fd91           4.282936e-08
#
#                                   photochemical ozone creation  \
# 379388913fee422a915764b6a021fd91                      0.000901
#
#                                   respiratory effects, inorganics  land use
# 379388913fee422a915764b6a021fd91                         0.000758  0.311929

# %%
# Compute with algebric implementation : the values should be the same
multiLCAAlgebric(
    elec_switch, # The model 
    impacts, # Impacts
    
    # Parameters of the model
    a=1, 
    b=2,
    elec_switch_param="us")
# Out:
#    mineral, fossils and renewables  GWP 100a  \
# 0                         0.000003  0.662856
#
#    freshwater and terrestrial acidification  freshwater ecotoxicity  \
# 0                                  0.002418                0.195917
#
#    freshwater eutrophication  ionising radiation  marine eutrophication  \
# 0                   0.000079        6.013195e-07               0.000281
#
#    terrestrial eutrophication  carcinogenic effects  ionising radiation  \
# 0                    0.003751          5.199518e-09            0.077193
#
#    non-carcinogenic effects  ozone layer depletion  \
# 0              4.209638e-08           4.282936e-08
#
#    photochemical ozone creation  respiratory effects, inorganics  land use
# 0                      0.000901                         0.000758  0.311929

# %%
# Here is what the symbolic model looks like 
expr, _ = actToExpression(model)
expr
# Out:
# 0.4*a*aluminium_alloy_production_almg3 + 3*heat_waste + (a + 5*b + 1)*(4*elec_switch_param_eu*market_group_for_electricity_medium_voltage1 + 4*elec_switch_param_us*market_group_for_electricity_medium_voltage + heat_waste*(b + 0.2) + occupation_industrial_area*(a + 3))

# %%
# Fast computation for millions of separate samples
multiLCAAlgebric(
    model, # The model 
    impacts, # Impacts
    
    # Parameters of the model
    a=list(range(1, 100000)), # LIst should be the same size for each param
    b=list(range(1, 100000)),
    elec_switch_param="eu")
# Out:
#        mineral, fossils and renewables      GWP 100a  \
# 0                             0.004127  1.428818e+01
# 1                             0.008239  2.686270e+01
# 2                             0.012351  3.943722e+01
# 3                             0.016463  5.201174e+01
# 4                             0.020575  6.458625e+01
# ...                                ...           ...
# 99994                       411.199369  1.257391e+06
# 99995                       411.203481  1.257403e+06
# 99996                       411.207593  1.257416e+06
# 99997                       411.211705  1.257428e+06
# 99998                       411.215817  1.257441e+06
#
#        freshwater and terrestrial acidification  freshwater ecotoxicity  \
# 0                                      0.090873                5.290014
# 1                                      0.170798               10.160906
# 2                                      0.250723               15.031798
# 3                                      0.330648               19.902690
# 4                                      0.410573               24.773582
# ...                                         ...                     ...
# 99994                               7992.114593           487065.281454
# 99995                               7992.194518           487070.152347
# 99996                               7992.274443           487075.023239
# 99997                               7992.354368           487079.894131
# 99998                               7992.434293           487084.765023
#
#        freshwater eutrophication  ionising radiation  marine eutrophication  \
# 0                       0.001505            0.000015               0.009431
# 1                       0.002816            0.000029               0.017789
# 2                       0.004127            0.000042               0.026146
# 3                       0.005437            0.000055               0.034503
# 4                       0.006748            0.000068               0.042860
# ...                          ...                 ...                    ...
# 99994                 131.046152            1.320076             835.665241
# 99995                 131.047463            1.320089             835.673599
# 99996                 131.048773            1.320102             835.681956
# 99997                 131.050084            1.320115             835.690313
# 99998                 131.051395            1.320129             835.698670
#
#        terrestrial eutrophication  carcinogenic effects  ionising radiation  \
# 0                        0.168374          2.147377e-07            1.891566
# 1                        0.315800          4.157202e-07            3.521138
# 2                        0.463226          6.167028e-07            5.150710
# 3                        0.610652          8.176854e-07            6.780282
# 4                        0.758078          1.018668e-06            8.409854
# ...                           ...                   ...                 ...
# 99994                14741.882529          2.009727e-02       162949.325875
# 99995                14742.029955          2.009747e-02       162950.955447
# 99996                14742.177381          2.009767e-02       162952.585019
# 99997                14742.324807          2.009787e-02       162954.214591
# 99998                14742.472233          2.009807e-02       162955.844163
#
#        non-carcinogenic effects  ozone layer depletion  \
# 0                      0.000002               0.000001
# 1                      0.000004               0.000002
# 2                      0.000005               0.000004
# 3                      0.000007               0.000005
# 4                      0.000009               0.000006
# ...                         ...                    ...
# 99994                  0.172879               0.114795
# 99995                  0.172881               0.114796
# 99996                  0.172883               0.114797
# 99997                  0.172885               0.114798
# 99998                  0.172886               0.114799
#
#        photochemical ozone creation  respiratory effects, inorganics  \
# 0                          0.028514                         0.008068
# 1                          0.053895                         0.015422
# 2                          0.079277                         0.022776
# 3                          0.104659                         0.030131
# 4                          0.130041                         0.037485
# ...                             ...                              ...
# 99994                   2538.069502                       735.407374
# 99995                   2538.094884                       735.414728
# 99996                   2538.120266                       735.422083
# 99997                   2538.145648                       735.429437
# 99998                   2538.171030                       735.436791
#
#            land use
# 0      4.239340e+02
# 1      9.799657e+02
# 2      1.713597e+03
# 3      2.624829e+03
# 4      3.713661e+03
# ...             ...
# 99994  8.879402e+11
# 99995  8.879579e+11
# 99996  8.879757e+11
# 99997  8.879935e+11
# 99998  8.880112e+11
#
# [99999 rows x 15 columns]
